# %% [markdown]
# ### Loading data

# %%
from sqlalchemy import create_engine
import pandas as pd

# Define the connection details
server = 'DESKTOP-D57LVN9\SQLEXPRESS'
database = 'ContosoRetail'
username = 'sa'
password = '281202'

# Create the connection string
connection_string = f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server'

# Create the engine
engine = create_engine(connection_string)

# Write SQL query
query = "select * from ContosoRetail_df"

# Load data into a pandas DataFrame
df_origin = pd.read_sql(query, engine, index_col='SalesKey')

# No need to explicitly close the engine, but it’s good practice to dispose of it when done
engine.dispose()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\duyvn\AppData\Local\Temp\ipykernel_15668\3841218430.py:5: SyntaxWarning: invalid escape sequence '\S'
#   server = 'DESKTOP-D57LVN9\SQLEXPRESS'

# %%
df_origin.head(5)
# Out:
#             DateKey ChannelName                       StoreName  \
# SalesKey
# 1        2022-01-02       Store           Contoso Baildon Store
# 2        2022-02-12    Reseller  Contoso North America Reseller
# 3        2023-01-24       Store         Contoso Cambridge Store
# 4        2023-01-13      Online     Contoso Europe Online Store
# 5        2023-01-22      Online     Contoso Europe Online Store
#
#           ContinentName         Country       City  \
# SalesKey
# 1                Europe  United Kingdom    Baildon
# 2         North America   United States    Seattle
# 3                Europe  United Kingdom  Cambridge
# 4                Europe         Germany     Berlin
# 5                Europe         Germany     Berlin
#
#                                                 ProductName  \
# SalesKey
# 1            A. Datum Point Shoot Digital Camera M500 Black
# 2                 Contoso Battery charger - bike E200 Black
# 3          Fabrikam Budget Moviemaker 2/3'' 17mm E100 White
# 4         The Phone Company Touch Screen Phones 4-Wire/O...
# 5                         Fabrikam SLR Camera 35" X358 Blue
#
#                   ProductCategory                   PromotionName  UnitCost  \
# SalesKey
# 1         Cameras and camcorders       European Holiday Promotion     91.05
# 2                       Computers  North America Spring Promotion     10.15
# 3         Cameras and camcorders   North America Spring Promotion    209.03
# 4                     Cell phones      European Holiday Promotion    132.90
# 5         Cameras and camcorders       European Holiday Promotion    144.52
#
#           UnitPrice  SalesQuantity  ReturnQuantity  ReturnAmount  \
# SalesKey
# 1             198.0              8               0           0.0
# 2              19.9              4               0           0.0
# 3             410.0              9               0           0.0
# 4             289.0              8               0           0.0
# 5             436.2             24               0           0.0
#
#           DiscountQuantity  DiscountAmount  TotalCost  SalesAmount
# SalesKey
# 1                        1          39.600     728.40     1544.400
# 2                        1           0.995      40.60       78.605
# 3                        3          61.500    1881.27     3628.500
# 4                        1          57.800    1063.20     2254.200
# 5                        3         261.720    3468.48    10207.080

# %% [markdown]
# ### Copying dataframe

# %%
df = df_origin.copy()

# %% [markdown]
# ### Exploring data
# By using `info()`, we can get a concise summary of the DataFrame that we will be using
# This method will give us:
# - Total records (rows) in the Dataframe
# - Numbers of columns
# - Columns name
# - Datatypes of each columns
# - Count of non-null values in each column

# %%
# Checking datatypes
df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3406089 entries, 1 to 3406089
# Data columns (total 18 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   DateKey           datetime64[ns]
#  1   ChannelName       object
#  2   StoreName         object
#  3   ContinentName     object
#  4   Country           object
#  5   City              object
#  6   ProductName       object
#  7   ProductCategory   object
#  8   PromotionName     object
#  9   UnitCost          float64
#  10  UnitPrice         float64
#  11  SalesQuantity     int64
#  12  ReturnQuantity    int64
#  13  ReturnAmount      float64
#  14  DiscountQuantity  int64
#  15  DiscountAmount    float64
#  16  TotalCost         float64
#  17  SalesAmount       float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(8)
# memory usage: 493.7+ MB

# %% [markdown]
# ### Summarizing key statistics of numerical data
# Using `describe()`, we can get a concise summary of each numerical data:
# - The central tendencies (mean, median).
# - Spread (standard deviation, percentiles).
# - Range (min, max) for numerical columns.
#
# In my DataFrame, the `DateKey` column is not considered as a numerical column, but when I use `describe()` on the DataFrame, this method will consider this column as a numerical column
#
# In that case, I decided to remove the `DateKey` column, then I will apply `describe()` on the DataFrame

# %%
# Exploring data 
df.drop(columns='DateKey').describe().map("{:.2f}".format)
# Out:
#          UnitCost   UnitPrice SalesQuantity ReturnQuantity ReturnAmount  \
# count  3406089.00  3406089.00    3406089.00     3406089.00   3406089.00
# mean       137.01      320.49         15.65           0.14        46.05
# std        167.56      428.58         33.61           0.36       202.51
# min          0.48        0.95          2.00           0.00         0.00
# 25%         32.19       68.00          9.00           0.00         0.00
# 50%         84.12      190.00         10.00           0.00         0.00
# 75%        166.20      369.00         13.00           0.00         0.00
# max       1060.22     3199.99       2880.00           5.00      9996.00
#
#       DiscountQuantity DiscountAmount   TotalCost SalesAmount
# count       3406089.00     3406089.00  3406089.00  3406089.00
# mean              1.49          59.94     1575.09     3644.55
# std               1.83         164.51     2110.97     5312.44
# min               0.00           0.00        1.92        3.04
# 25%               0.00           0.00      305.85      611.94
# 50%               1.00           2.53      943.28     2105.88
# 75%               3.00          51.60     2024.73     4557.10
# max              24.00        7958.70   137117.76   408016.02

# %% [markdown]
# ### General observations after `describe()`
# - **Large dataset**: The total records of each columns are the same (over 3.4 million entries), indicating a significant amount of data.
# - **Consistency**: There seem to be no missing values in any columns (`count` is the same for all columns)
